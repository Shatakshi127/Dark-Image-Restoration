# %% [markdown]
# <a href="https://colab.research.google.com/github/NamanChaudhary1/Low-Light-Image-Enhancement-Using-CNN/blob/main/NamanChaudhary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import cv2 as cv
import matplotlib.pyplot as plt
from keras import backend as K
from keras.layers import add, Conv2D,MaxPooling2D,UpSampling2D,Input,BatchNormalization, RepeatVector, Reshape
from keras.models import Model
np.random.seed(2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
InputPath = "/content/drive/MyDrive/LOLdataset/our485/high/"

# %%
def noisy(noise_typ, image):
    if noise_typ == "s&p":
        row, col, ch = image.shape
        s_vs_p = 0.5
        amount = 1
        noisy_image = np.copy(image)

        # Salt mode
        num_salt = np.ceil(image.size * s_vs_p)
        salt_coords = [np.random.randint(0, i, int(num_salt)) for i in image.shape]
        noisy_image[tuple(salt_coords)] = 1

        # Pepper mode
        num_pepper = np.ceil(image.size * (1.0 - s_vs_p))
        pepper_coords = [np.random.randint(0, i, int(num_pepper)) for i in image.shape]
        noisy_image[tuple(pepper_coords)] = 1

        return noisy_image

# %% [markdown]
# REAL IMAGE

# %%
img = cv.imread(InputPath+"477.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
l = img.max()
plt.imshow(img)
l
# Out:
# 242

# %% [markdown]
# ADD NOISE TO IT

# %%
Noise = noisy("s&p",img)
plt.imshow(Noise)

# %% [markdown]
# GETTING PERFECT LOW ON LIGHT IMAGE

# %%
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV) #convert it to hsv
hsv[...,2] = hsv[...,2]*0.2
img1 = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
Noise2 = noisy("s&p",img1)

plt.imshow(Noise2)

# %%
def PreProcessData(ImagePath):
    X_=[]
    y_=[]
    count=0
    for imageDir in os.listdir(ImagePath):
        if count<2131:
            try:
                count=count+1
                img = cv.imread(ImagePath + imageDir)
                img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
                img_y = cv.resize(img,(500,500))
                hsv = cv.cvtColor(img_y, cv.COLOR_BGR2HSV) #convert it to hsv
                hsv[...,2] = hsv[...,2]*0.2
                img_1 = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
                Noisey_img = noisy("s&p",img_1)
                X_.append(Noisey_img)
                y_.append(img_y)
            except:
                pass
    X_ = np.array(X_)
    y_ = np.array(y_)

    return X_,y_

# %%
X_,y_ = PreProcessData(InputPath)

# %%
K.clear_session()
def InstantiateModel(in_):
  # Layer 1: Low-level feature extraction using 16 filters
    model_1 = Conv2D(16, (3, 3), activation='relu', padding='same', strides=1)(in_)

    # Layer 2: Increase complexity with 32 filters
    model_1 = Conv2D(32, (3, 3), activation='relu', padding='same', strides=1)(model_1)

    # Layer 3: Further complexity with 64 filters
    model_1 = Conv2D(64, (2, 2), activation='relu', padding='same', strides=1)(model_1)

    # Layer 4: Low-level feature extraction using 32 filters
    model_2 = Conv2D(32, (3, 3), activation='relu', padding='same', strides=1)(in_)

    # Layer 5: Increase complexity with 64 filters
    model_2 = Conv2D(64, (2, 2), activation='relu', padding='same', strides=1)(model_2)

    # Layer 6: Further complexity with 64 filters
    model_2_0 = Conv2D(64, (2, 2), activation='relu', padding='same', strides=1)(model_2)

    # Combine features from model_1 and model_2 branches
    model_add = add([model_1, model_2, model_2_0])

    # Define the final model output
    model_output = Conv2D(3, (3, 3), activation='relu', padding='same', strides=1)(model_add)


    return model_output

# %%
Input_Sample = Input(shape=(500, 500,3))
Output_ = InstantiateModel(Input_Sample)
Model_Enhancer = Model(inputs=Input_Sample, outputs=Output_)
Model_Enhancer.compile(optimizer="adam", loss='mean_squared_error')
Model_Enhancer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 500, 500, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 500, 500, 16)         448       ['input_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 500, 500, 32)         896       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 500, 500, 32)         4640      ['conv2d[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 500, 500, 64)         8256      ['conv2d_3[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 500, 500, 64)         8256      ['conv2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 500, 500, 64)         16448     ['conv2d_4[0][0]']
#
#  add (Add)                   (None, 500, 500, 64)         0         ['conv2d_2[0][0]',
#                                                                      'conv2d_4[0][0]',
#                                                                      'conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 500, 500, 3)          1731      ['add[0][0]']
#
# ==================================================================================================
# Total params: 40675 (158.89 KB)
# Trainable params: 40675 (158.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(Model_Enhancer,to_file='model_.png',show_shapes=True, show_layer_names=True)
from IPython.display import Image
Image(retina=True, filename='model_.png')

# %%
def GenerateInputs(X,y):
    for i in range(len(X)):
        X_input = X[i].reshape(1,500,500,3)
        y_input = y[i].reshape(1,500,500,3)
        yield (X_input,y_input)
Model_Enhancer.fit_generator(GenerateInputs(X_,y_),epochs=53,verbose=1,steps_per_epoch=8,shuffle=True)
# Out:
# Epoch 1/53
# <ipython-input-16-48fe1ba6f2d0>:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   Model_Enhancer.fit_generator(GenerateInputs(X_,y_),epochs=53,verbose=1,steps_per_epoch=8,shuffle=True)
# 8/8 [==============================] - 13s 42ms/step - loss: 8505.7021
# Epoch 2/53
# 8/8 [==============================] - 0s 42ms/step - loss: 1719.5266
# Epoch 3/53
# 8/8 [==============================] - 0s 42ms/step - loss: 838.7330
# Epoch 4/53
# 8/8 [==============================] - 0s 43ms/step - loss: 516.3612
# Epoch 5/53
# 8/8 [==============================] - 0s 43ms/step - loss: 571.3036
# Epoch 6/53
# 8/8 [==============================] - 0s 43ms/step - loss: 466.9184
# Epoch 7/53
# 8/8 [==============================] - 0s 42ms/step - loss: 511.9441
# Epoch 8/53
# 8/8 [==============================] - 0s 41ms/step - loss: 407.3619
# Epoch 9/53
# 8/8 [==============================] - 0s 42ms/step - loss: 361.1349
# Epoch 10/53
# 8/8 [==============================] - 0s 44ms/step - loss: 447.3272
# Epoch 11/53
# 8/8 [==============================] - 0s 42ms/step - loss: 334.1260
# Epoch 12/53
# 8/8 [==============================] - 0s 43ms/step - loss: 356.4191
# Epoch 13/53
# 8/8 [==============================] - 0s 43ms/step - loss: 318.3389
# Epoch 14/53
# 8/8 [==============================] - 0s 43ms/step - loss: 312.8742
# Epoch 15/53
# 8/8 [==============================] - 0s 43ms/step - loss: 375.7293
# Epoch 16/53
# 8/8 [==============================] - 0s 44ms/step - loss: 370.5930
# Epoch 17/53
# 8/8 [==============================] - 0s 44ms/step - loss: 373.0402
# Epoch 18/53
# 8/8 [==============================] - 0s 44ms/step - loss: 519.7423
# Epoch 19/53
# 8/8 [==============================] - 0s 44ms/step - loss: 512.3507
# Epoch 20/53
# 8/8 [==============================] - 0s 43ms/step - loss: 383.0858
# Epoch 21/53
# 8/8 [==============================] - 0s 43ms/step - loss: 335.1348
# Epoch 22/53
# 8/8 [==============================] - 0s 42ms/step - loss: 474.0896
# Epoch 23/53
# 8/8 [==============================] - 0s 43ms/step - loss: 312.0853
# Epoch 24/53
# 8/8 [==============================] - 0s 42ms/step - loss: 280.2950
# Epoch 25/53
# 8/8 [==============================] - 0s 42ms/step - loss: 274.8877
# Epoch 26/53
# 8/8 [==============================] - 0s 42ms/step - loss: 481.1737
# Epoch 27/53
# 8/8 [==============================] - 0s 42ms/step - loss: 442.5159
# Epoch 28/53
# 8/8 [==============================] - 0s 42ms/step - loss: 339.0677
# Epoch 29/53
# 8/8 [==============================] - 0s 43ms/step - loss: 423.7490
# Epoch 30/53
# 8/8 [==============================] - 0s 42ms/step - loss: 327.9166
# Epoch 31/53
# 8/8 [==============================] - 0s 41ms/step - loss: 344.7240
# Epoch 32/53
# 8/8 [==============================] - 0s 42ms/step - loss: 330.4099
# Epoch 33/53
# 8/8 [==============================] - 0s 43ms/step - loss: 379.9230
# Epoch 34/53
# 8/8 [==============================] - 0s 42ms/step - loss: 289.6862
# Epoch 35/53
# 8/8 [==============================] - 0s 43ms/step - loss: 274.2816
# Epoch 36/53
# 8/8 [==============================] - 0s 43ms/step - loss: 332.9173
# Epoch 37/53
# 8/8 [==============================] - 0s 42ms/step - loss: 302.2587
# Epoch 38/53
# 8/8 [==============================] - 0s 43ms/step - loss: 402.7515
# Epoch 39/53
# 8/8 [==============================] - 0s 43ms/step - loss: 274.5559
# Epoch 40/53
# 8/8 [==============================] - 0s 42ms/step - loss: 394.1106
# Epoch 41/53
# 8/8 [==============================] - 0s 42ms/step - loss: 263.9742
# Epoch 42/53
# 8/8 [==============================] - 0s 43ms/step - loss: 279.8041
# Epoch 43/53
# 8/8 [==============================] - 0s 42ms/step - loss: 289.8036
# Epoch 44/53
# 8/8 [==============================] - 0s 42ms/step - loss: 225.7291
# Epoch 45/53
# 8/8 [==============================] - 0s 42ms/step - loss: 277.3460
# Epoch 46/53
# 8/8 [==============================] - 0s 42ms/step - loss: 278.1079
# Epoch 47/53
# 8/8 [==============================] - 0s 43ms/step - loss: 241.1851
# Epoch 48/53
# 8/8 [==============================] - 0s 42ms/step - loss: 374.3076
# Epoch 49/53
# 8/8 [==============================] - 0s 43ms/step - loss: 255.1918
# Epoch 50/53
# 8/8 [==============================] - 0s 43ms/step - loss: 256.9268
# Epoch 51/53
# 8/8 [==============================] - 0s 44ms/step - loss: 258.9344
# Epoch 52/53
# 8/8 [==============================] - 0s 44ms/step - loss: 277.5807
# Epoch 53/53
# 8/8 [==============================] - 0s 45ms/step - loss: 189.5608

# %%
TestPath="/content/drive/MyDrive/LOLdataset/our485/high/"

# %%
def ExtractTestInput(ImagePath):
    img = cv.imread(ImagePath)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img_ = cv.resize(img,(500,500))
    hsv = cv.cvtColor(img_, cv.COLOR_BGR2HSV) #convert it to hsv
    hsv[...,2] = hsv[...,2]*0.2
    img1 = cv.cvtColor(hsv, cv.COLOR_HSV2BGR)
    Noise = noisy("s&p",img1)
    Noise = Noise.reshape(1,500,500,3)
    return Noise

# %%
ImagePath=TestPath+"112.png"
plt.figure(figsize=(30,30))
plt.subplot(5,5,1)
img_1 = cv.imread(ImagePath)
img_1 = cv.cvtColor(img_1, cv.COLOR_BGR2RGB)
img_1 = cv.resize(img_1, (500, 500))
plt.title("Ground Truth",fontsize=20)
plt.imshow(img_1)

plt.subplot(5,5,1+1)
img_ = ExtractTestInput(ImagePath)
img_ = img_.reshape(500,500,3)
plt.title("Low Light Image",fontsize=20)
plt.imshow(img_)

plt.subplot(5,5,1+2)
image_for_test = ExtractTestInput(ImagePath)
Prediction = Model_Enhancer.predict(image_for_test)
Prediction = Prediction.reshape(500,500,3)
img_[:,:,:] = Prediction[:,:,:]
plt.title("Enhanced Image",fontsize=20)
plt.imshow(img_)
# Out:
# 1/1 [==============================] - 0s 363ms/step
